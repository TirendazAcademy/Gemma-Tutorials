# %% [markdown]
# <a href="https://colab.research.google.com/github/TirendazAcademy/Gemma-Tutorials/blob/main/how_to_work_with_gemma_2b_it.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU "transformers==4.38.0" --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 27.5 MB/s eta 0:00:00

# %%
import torch
from transformers import AutoTokenizer

model = "google/gemma-2b-it"

tokenizer = AutoTokenizer.from_pretrained(model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.15k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/888 [00:00<?, ?B/s]

# %%
from transformers import pipeline

pipeline = pipeline(
    "text-generation",
    model=model,
    model_kwargs={"torch_dtype": torch.bfloat16},
    device="cuda",
)
# Out:
# config.json:   0%|          | 0.00/627 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
messages = [
        {"role": "user", "content": "Who are you? Please, answer in pirate-speak."},
]

# %%
prompt = pipeline.tokenizer.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True)

# %%
outputs = pipeline(
    prompt,
    max_new_tokens=256,
    add_special_tokens=True,
    do_sample=True,
    temperature=0.7,
    top_k=50,
    top_p=0.95
)

# %%
print(outputs[0]["generated_text"][len(prompt):])
# Out:
# Ahoy, me hearties! I be the mighty Calico Jack, the kraken of the seven seas. I walk the plank of reason, but I swim the waves of laughter. I be a scurvy-smit, a buccaneer of the highest order, and I be here to plunder the treasures of knowledge!
#
# So, if you be lookin' for a matey with a wit as sharp as a parrot's beak and a belly full of stories, then come sail with me, matey! I'll show ye the secrets of the seven seas, and I'll tell ye tales that'll make yer eyes go wide!
